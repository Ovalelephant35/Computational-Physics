# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1-Basic Introduction to Libraries.

# %%
a1 = np.array([3,5,7,9])
a2 = np.linspace(0,10,5)
print(a2)
print(a1)
a1>4

# %%
x=np.linspace(0,100,100)
y=x**2 + x - 5
plt.plot(x,y)
