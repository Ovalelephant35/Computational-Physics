# %%
a = ["cat"  ,5 , 1  , 2 , [7,8] ]
print(a)
print(a[4])
#list uses the square brackets
# Out:
# ['cat', 5, 1, 2, [7, 8]]
# [7, 8]

# %%
a[0] = "Dog"
print(a)

# %%
a = a*2
print(a)
# Out:
# ['Dog', 5, 1, 2, [7, 8], 'Dog', 5, 1, 2, [7, 8]]

# %%
b = [23, 'python' , 'cpp']
c = a+b
print(c)
# Out:
# ['Dog', 5, 1, 2, [7, 8], 'Dog', 5, 1, 2, [7, 8], 23, 'python', 'cpp']

# %%
li = (1 , 2 , 3 , 'apple')
print(li)
#we can see this immutable this is tuple it cannot be changed
#tuples uses the normal brackets
# Out:
# {1, 2, 3, 'apple'}

# %%
di= {"cat" : "dog" }
print(di["cat"])
#Dictionary basically is assigning different values to different objects also it uses curly brackets
# Out:
# dog

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-100 , 100, 200)
y = x**3
plt.plot(x,y)

# %%
import numpy as np
x=np.array([1,2,4,2])
print(x)
x= 2*x
print(x)
x= np.linspace(0,100,100)
print(x)
x=np.arange(0 , 20 , 2)
print(x)
